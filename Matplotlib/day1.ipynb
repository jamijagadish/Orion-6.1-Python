# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [10, 15, 25, 40]

plt.plot(x,y)

# %%
plt.plot(x,y, color='r')

# %%
plt.plot(x,y, color='green')

# %%
plt.plot(x,y, color='maroon')

# %%
plt.plot(x,y, color='g', linestyle='-')

# %%
plt.plot(x,y, color='g', linestyle='--')

# %%
plt.plot(x,y, color='g', linestyle='-.')

# %%
plt.plot(x,y, color='g', linestyle='dotted')

# %%
plt.plot(x,y, color='g', linestyle=(0, (5,10)))

# %%
plt.plot(x,y, color='g', linestyle='--', marker='+')

# %%
plt.plot(x,y, color='g', linestyle='--', marker = 'o')

# %%
plt.plot(x,y, color='g', linestyle='--', marker = '1')

# %%
plt.plot(x,y, color='g', linestyle='--', marker = 1)

# %%
plt.plot(x,y, 'y+--')

# %%
plt.plot(x,y, color='g', linestyle='--', marker ='o', markersize=15)

# %%
plt.plot(x,y, color='g', linestyle='--', marker ='o', markersize=15, linewidth= 5)

# %%
plt.plot(x,y, color='g', linestyle='--', marker ='o', markersize=15, linewidth= 5, alpha=0.25)
plt.plot([2,3,5,6], [20,35,40,50], 'r+-.')
plt.xlabel('Numbers')
plt.ylabel('Price')
plt.legend(loc='upper right', title='Price Chart')
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_15396\1296423150.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='upper right', title='Price Chart')

# %%
plt.plot(x,y, color='g', linestyle='--', marker ='o', markersize=15, linewidth= 5, alpha=0.25)
plt.plot([2,3,5,6], [20,35,40,50], 'r+-.')
plt.xlabel('Numbers')
plt.ylabel('Price')
plt.legend(loc='right', title='Price Chart')
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_15396\3272632282.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='right', title='Price Chart')

# %%
plt.plot(x,y, color='g', linestyle='--', marker ='o', markersize=15, linewidth= 5, alpha=0.25)
plt.plot([2,3,5,6], [20,35,40,50], 'r+-.')
plt.xlabel('Numbers')
plt.ylabel('Price')
plt.legend(loc='best', title='Price Chart')
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_15396\1808758944.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='best', title='Price Chart')
