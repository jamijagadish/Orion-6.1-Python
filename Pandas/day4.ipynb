# %%
import pandas as pd

# %% [markdown]
# # Handling Missing Data

# %%
df = pd.read_csv('customers-100.csv')
df.head()
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl    Baxter           Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston    Lozano                       NaN
# 2    NaN              NaN        NaN       NaN                       NaN
# 3    NaN              NaN        NaN       NaN                       NaN
# 4    5.0  053d585Ab6b3159     Joanna       NaN  Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0                NaN                       Chile                     NaN
# 1  East Jimmychester                    Djibouti              5153435776
# 2                NaN                         NaN                     NaN
# 3                NaN                         NaN                     NaN
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
#                  Phone 2                     Email Subscription Date  \
# ...

# %%
df['Subscription Date']
# Out:
# 0     24-08-2020
# 1     23-04-2021
# 2            NaN
# 3            NaN
# 4     17-04-2021
#          ...
# 95    30-01-2022
# 96    10-07-2021
# 97    18-09-2021
# 98    11-08-2021
# 99    11-03-2020
# Name: Subscription Date, Length: 100, dtype: object

# %%
type(df['Subscription Date'][0])
# Out:
# str

# %%
df = pd.read_csv('customers-100.csv', parse_dates=['Subscription Date'])
type(df['Subscription Date'][0])
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_20612\149584795.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv('customers-100.csv', parse_dates=['Subscription Date'])
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl    Baxter           Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston    Lozano                       NaN
# 2    NaN              NaN        NaN       NaN                       NaN
# 3    NaN              NaN        NaN       NaN                       NaN
# 4    5.0  053d585Ab6b3159     Joanna       NaN  Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0                NaN                       Chile                     NaN
# 1  East Jimmychester                    Djibouti              5153435776
# 2                NaN                         NaN                     NaN
# 3                NaN                         NaN                     NaN
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
#                  Phone 2                     Email Subscription Date  \
# ...

# %%
df2 = df.fillna("0")
df2.head(10)
# Out:
#   Index      Customer Id First Name  Last Name                       Company  \
# 0   1.0  DD37Cf93aecA6Dc     Sheryl     Baxter               Rasmussen Group
# 1   2.0  1Ef7b82A4CAAD10    Preston     Lozano                             0
# 2     0                0          0          0                             0
# 3     0                0          0          0                             0
# 4   5.0  053d585Ab6b3159     Joanna          0      Martin, Lang and Andrade
# 5     0                0          0          0                             0
# 6   7.0  EA4d384DfDbBf77     Darren          0  Lester, Woodard and Mitchell
# 7   8.0  0e04AFde9f225dE      Brett     Mullen  Sanford, Davenport and Giles
# 8   9.0  C2dE4dEEc489ae0     Sheryl     Meyers                Browning-Simon
# 9  10.0  8C2811a503C7c5a   Michelle  Gallagher                  Beck-Hendrix
#
#                 City                     Country                 Phone 1  \
# ...

# %%
df3 = df.fillna({
    'Last Name': "No Last name",
    'Company': "No Company",
    'City': "No City",
    'Country': "No Country"
})
df3.head(10)
# Out:
#    Index      Customer Id First Name     Last Name  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl        Baxter
# 1    2.0  1Ef7b82A4CAAD10    Preston        Lozano
# 2    NaN              NaN        NaN  No Last name
# 3    NaN              NaN        NaN  No Last name
# 4    5.0  053d585Ab6b3159     Joanna  No Last name
# 5    NaN              NaN        NaN  No Last name
# 6    7.0  EA4d384DfDbBf77     Darren  No Last name
# 7    8.0  0e04AFde9f225dE      Brett        Mullen
# 8    9.0  C2dE4dEEc489ae0     Sheryl        Meyers
# 9   10.0  8C2811a503C7c5a   Michelle     Gallagher
#
#                         Company               City  \
# 0               Rasmussen Group            No City
# 1                    No Company  East Jimmychester
# 2                    No Company            No City
# 3                    No Company            No City
# 4      Martin, Lang and Andrade     West Priscilla
# 5                    No Company            No City
# ...

# %%
df.head(6)
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl    Baxter           Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston    Lozano                       NaN
# 2    NaN              NaN        NaN       NaN                       NaN
# 3    NaN              NaN        NaN       NaN                       NaN
# 4    5.0  053d585Ab6b3159     Joanna       NaN  Martin, Lang and Andrade
# 5    NaN              NaN        NaN       NaN                       NaN
#
#                 City                     Country                 Phone 1  \
# 0                NaN                       Chile                     NaN
# 1  East Jimmychester                    Djibouti              5153435776
# 2                NaN                         NaN                     NaN
# 3                NaN                         NaN                     NaN
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
# ...

# %%
df4 = df.fillna(method='ffill')
df4.head(10)
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_20612\2814763064.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df4 = df.fillna(method='ffill')
#    Index      Customer Id First Name  Last Name                       Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl     Baxter               Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston     Lozano               Rasmussen Group
# 2    2.0  1Ef7b82A4CAAD10    Preston     Lozano               Rasmussen Group
# 3    2.0  1Ef7b82A4CAAD10    Preston     Lozano               Rasmussen Group
# 4    5.0  053d585Ab6b3159     Joanna     Lozano      Martin, Lang and Andrade
# 5    5.0  053d585Ab6b3159     Joanna     Lozano      Martin, Lang and Andrade
# 6    7.0  EA4d384DfDbBf77     Darren     Lozano  Lester, Woodard and Mitchell
# 7    8.0  0e04AFde9f225dE      Brett     Mullen  Sanford, Davenport and Giles
# ...

# %%
df4 = df.fillna(method='bfill')
df4.head(10)
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_20612\3031610167.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df4 = df.fillna(method='bfill')
#    Index      Customer Id First Name  Last Name                       Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl     Baxter               Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston     Lozano      Martin, Lang and Andrade
# 2    5.0  053d585Ab6b3159     Joanna     Mullen      Martin, Lang and Andrade
# 3    5.0  053d585Ab6b3159     Joanna     Mullen      Martin, Lang and Andrade
# 4    5.0  053d585Ab6b3159     Joanna     Mullen      Martin, Lang and Andrade
# 5    7.0  EA4d384DfDbBf77     Darren     Mullen  Lester, Woodard and Mitchell
# 6    7.0  EA4d384DfDbBf77     Darren     Mullen  Lester, Woodard and Mitchell
# 7    8.0  0e04AFde9f225dE      Brett     Mullen  Sanford, Davenport and Giles
# ...

# %%
df6 = df.fillna(method='ffill', axis='columns')
df6.head(7)
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_20612\4205172241.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df6 = df.fillna(method='ffill', axis='columns')
# C:\Users\91801\AppData\Local\Temp\ipykernel_20612\4205172241.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df6 = df.fillna(method='ffill', axis='columns')
#   Index      Customer Id First Name Last Name                       Company  \
# 0   1.0  DD37Cf93aecA6Dc     Sheryl    Baxter               Rasmussen Group
# 1   2.0  1Ef7b82A4CAAD10    Preston    Lozano                        Lozano
# 2   NaN              NaN        NaN       NaN                           NaN
# ...

# %%
df6 = df.fillna(method='bfill', axis='columns')
df6.head()
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_20612\2093781745.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df6 = df.fillna(method='bfill', axis='columns')
# C:\Users\91801\AppData\Local\Temp\ipykernel_20612\2093781745.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df6 = df.fillna(method='bfill', axis='columns')
#                  Index          Customer Id           First Name  \
# 0                  1.0      DD37Cf93aecA6Dc               Sheryl
# 1                  2.0      1Ef7b82A4CAAD10              Preston
# 2  beckycarr@hogan.com  beckycarr@hogan.com  beckycarr@hogan.com
# 3                  NaN                  NaN                  NaN
# ...

# %%
df7 = df.fillna(method='ffill', limit = 2)
df7.head(10)
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_20612\3555507922.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df7 = df.fillna(method='ffill', limit = 2)
#    Index      Customer Id First Name  Last Name                       Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl     Baxter               Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston     Lozano               Rasmussen Group
# 2    2.0  1Ef7b82A4CAAD10    Preston     Lozano               Rasmussen Group
# 3    2.0  1Ef7b82A4CAAD10    Preston     Lozano                           NaN
# 4    5.0  053d585Ab6b3159     Joanna        NaN      Martin, Lang and Andrade
# 5    5.0  053d585Ab6b3159     Joanna        NaN      Martin, Lang and Andrade
# 6    7.0  EA4d384DfDbBf77     Darren        NaN  Lester, Woodard and Mitchell
# 7    8.0  0e04AFde9f225dE      Brett     Mullen  Sanford, Davenport and Giles
# ...

# %%
df8 = df.interpolate()
df8.head()
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_20612\2222141170.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df8 = df.interpolate()
#    Index      Customer Id First Name Last Name                   Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl    Baxter           Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston    Lozano                       NaN
# 2    3.0              NaN        NaN       NaN                       NaN
# 3    4.0              NaN        NaN       NaN                       NaN
# 4    5.0  053d585Ab6b3159     Joanna       NaN  Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0                NaN                       Chile                     NaN
# 1  East Jimmychester                    Djibouti              5153435776
# ...

# %%
df9 = df.interpolate(method='linear')
df9
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_20612\1151930254.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df9 = df.interpolate(method='polynomial', order=5)
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df9 = df.interpolate(method='polynomial', order=5)
#       2 df9
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:8518, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8516 else:
#    8517     index = missing.get_interp_index(method, obj.index)
# -> 8518     new_data = obj._mgr.interpolate(
#    8519         method=method,
#    8520         index=index,
#    8521         limit=limit,
# ...

# %%
df7 = df.dropna()
df7.head()
# Out:
#     Index      Customer Id First Name  Last Name  \
# 7     8.0  0e04AFde9f225dE      Brett     Mullen
# 8     9.0  C2dE4dEEc489ae0     Sheryl     Meyers
# 9    10.0  8C2811a503C7c5a   Michelle  Gallagher
# 10   11.0  216E205d6eBb815       Carl  Schroeder
# 11   12.0  CEDec94deE6d69B      Jenna     Dodson
#
#                          Company          City      Country  \
# 7   Sanford, Davenport and Giles       Kimport     Bulgaria
# 8                 Browning-Simon  Robersonstad       Cyprus
# 9                   Beck-Hendrix    Elaineberg  Timor-Leste
# 10    Oconnell, Meza and Everett  Shannonville     Guernsey
# 11     Hoffman, Reed and Mcclain   East Andrea      Vietnam
#
#                  Phone 1                Phone 2                    Email  \
# 7   001-583-352-7197x297       001-333-145-0369          asnow@colon.com
# 8      854-138-4911x5772    +1-448-910-2276x729  mariokhan@ryan-pope.org
# 9       739.218.2516x459   001-054-401-0347x617        mdyer@escobar.net
# ...

# %%
df8 = df.dropna(how="all")
df8.head(10)
# Out:
#     Index      Customer Id First Name  Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston     Lozano
# 2     NaN              NaN        NaN        NaN
# 4     5.0  053d585Ab6b3159     Joanna        NaN
# 5     NaN              NaN        NaN        NaN
# 6     7.0  EA4d384DfDbBf77     Darren        NaN
# 7     8.0  0e04AFde9f225dE      Brett     Mullen
# 8     9.0  C2dE4dEEc489ae0     Sheryl     Meyers
# 9    10.0  8C2811a503C7c5a   Michelle  Gallagher
# 10   11.0  216E205d6eBb815       Carl  Schroeder
#
#                          Company               City  \
# 0                Rasmussen Group                NaN
# 1                            NaN  East Jimmychester
# 2                            NaN                NaN
# 4       Martin, Lang and Andrade     West Priscilla
# 5                            NaN                NaN
# 6   Lester, Woodard and Mitchell           Lake Ana
# ...

# %%
df2 = df.dropna(thresh=1)
df2.head()
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl    Baxter           Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston    Lozano                       NaN
# 2    NaN              NaN        NaN       NaN                       NaN
# 3    NaN              NaN        NaN       NaN                       NaN
# 4    5.0  053d585Ab6b3159     Joanna       NaN  Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0                NaN                       Chile                     NaN
# 1  East Jimmychester                    Djibouti              5153435776
# 2                NaN                         NaN                     NaN
# 3                NaN                         NaN                     NaN
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
#                  Phone 2                     Email Subscription Date  \
# ...
