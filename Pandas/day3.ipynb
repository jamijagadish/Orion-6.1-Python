# %%
import pandas as pd

# %%
df = pd.read_csv("customers-100.csv")
df.head(10)
# Out:
#    Index      Customer Id First Name  Last Name                       Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl     Baxter               Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston     Lozano                           NaN
# 2    NaN              NaN        NaN        NaN                           NaN
# 3    NaN              NaN        NaN        NaN                           NaN
# 4    5.0  053d585Ab6b3159     Joanna        NaN      Martin, Lang and Andrade
# 5    NaN              NaN        NaN        NaN                           NaN
# 6    7.0  EA4d384DfDbBf77     Darren        NaN  Lester, Woodard and Mitchell
# 7    8.0  0e04AFde9f225dE      Brett     Mullen  Sanford, Davenport and Giles
# 8    9.0  C2dE4dEEc489ae0     Sheryl     Meyers                Browning-Simon
# 9   10.0  8C2811a503C7c5a   Michelle  Gallagher                  Beck-Hendrix
#
#                 City                     Country                 Phone 1  \
# ...

# %%
df = pd.read_csv("customers-100.csv", skiprows=15)
df.head()
# Out:
#    15  6fEaA1b7cab7B6C     Faith      Lutz      Carter-Hancock  \
# 0  16  8cad0b4CBceaeec   Miranda   Beasley  Singleton and Sons
# 1  17  a5DC21AE3a21eaA  Caroline     Foley     Winters-Mendoza
# 2  18  F8Aa9d6DfcBeeF8      Greg      Mata       Valentine LLC
# 3  19  F160f5Db3EfE973  Clifford  Jacobson           Simon LLC
# 4  20  0F60FF3DdCd7aB0    Joanna      Kirk      Mays-Mccormick
#
#            Burchbury                                     Singapore  \
# 0       Desireeshire                                          Oman
# 1  West Adriennestad                                Western Sahara
# 2        Lake Leslie                                    Mozambique
# 3         Harmonview  South Georgia and the South Sandwich Islands
# 4         Jamesshire                              French Polynesia
#
#       (781)861-7180x8306           207-185-3665  \
# 0       540.085.3135x185  +1-600-462-6432x21881
# 1      936.222.4746x9924   001-469-948-6341x359
# ...

# %%
df = pd.read_csv("customers-100.csv", header=15)
df
# Out:
#      15  6fEaA1b7cab7B6C     Faith      Lutz         Carter-Hancock  \
# 0    16  8cad0b4CBceaeec   Miranda   Beasley     Singleton and Sons
# 1    17  a5DC21AE3a21eaA  Caroline     Foley        Winters-Mendoza
# 2    18  F8Aa9d6DfcBeeF8      Greg      Mata          Valentine LLC
# 3    19  F160f5Db3EfE973  Clifford  Jacobson              Simon LLC
# 4    20  0F60FF3DdCd7aB0    Joanna      Kirk         Mays-Mccormick
# ..  ...              ...       ...       ...                    ...
# 80   96  cb8E23e48d22Eae      Karl     Greer              Carey LLC
# 81   97  CeD220bdAaCfaDf      Lynn  Atkinson  Ware, Burns and Oneal
# 82   98  28CDbC0dFe4b1Db      Fred    Guerra          Schmitt-Jones
# 83   99  c23d1D9EE8DEB0A    Yvonne    Farmer     Fitzgerald-Harrell
# 84  100  2354a0E336A91A1  Clarence    Haynes     Le, Nash and Cross
#
#             Burchbury                                     Singapore  \
# 0        Desireeshire                                          Oman
# ...

# %%
df = pd.read_csv("customers-100.csv", header=None)
df.head()
# Out:
#       0                1           2          3                4   \
# 0  Index      Customer Id  First Name  Last Name          Company
# 1      1  DD37Cf93aecA6Dc      Sheryl     Baxter  Rasmussen Group
# 2      2  1Ef7b82A4CAAD10     Preston     Lozano              NaN
# 3    NaN              NaN         NaN        NaN              NaN
# 4    NaN              NaN         NaN        NaN              NaN
#
#                   5         6           7                 8   \
# 0               City   Country     Phone 1           Phone 2
# 1                NaN     Chile         NaN  397.884.0519x718
# 2  East Jimmychester  Djibouti  5153435776  686-620-1820x944
# 3                NaN       NaN         NaN               NaN
# 4                NaN       NaN         NaN               NaN
#
#                          9                  10                          11
# 0                     Email  Subscription Date                     Website
# ...

# %%
df = pd.read_csv("customers-100.csv", header=None, names=["Col1", "Col2", "Col3", "Col4", "Col5", "Col6", "Col7", "Col8", "Col9", "Col10", "Col11"])
df.head()
# Out:
#                   Col1        Col2       Col3             Col4  \
# Index      Customer Id  First Name  Last Name          Company
# 1      DD37Cf93aecA6Dc      Sheryl     Baxter  Rasmussen Group
# 2      1Ef7b82A4CAAD10     Preston     Lozano              NaN
# NaN                NaN         NaN        NaN              NaN
# NaN                NaN         NaN        NaN              NaN
#
#                     Col5      Col6        Col7              Col8  \
# Index               City   Country     Phone 1           Phone 2
# 1                    NaN     Chile         NaN  397.884.0519x718
# 2      East Jimmychester  Djibouti  5153435776  686-620-1820x944
# NaN                  NaN       NaN         NaN               NaN
# NaN                  NaN       NaN         NaN               NaN
#
#                            Col9              Col10                       Col11
# Index                     Email  Subscription Date                     Website
# ...

# %%
df = pd.read_csv("customers-100.csv", nrows=10)
df
# Out:
#    Index      Customer Id First Name  Last Name                       Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl     Baxter               Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston     Lozano                           NaN
# 2    NaN              NaN        NaN        NaN                           NaN
# 3    NaN              NaN        NaN        NaN                           NaN
# 4    5.0  053d585Ab6b3159     Joanna        NaN      Martin, Lang and Andrade
# 5    NaN              NaN        NaN        NaN                           NaN
# 6    7.0  EA4d384DfDbBf77     Darren        NaN  Lester, Woodard and Mitchell
# 7    8.0  0e04AFde9f225dE      Brett     Mullen  Sanford, Davenport and Giles
# 8    9.0  C2dE4dEEc489ae0     Sheryl     Meyers                Browning-Simon
# 9   10.0  8C2811a503C7c5a   Michelle  Gallagher                  Beck-Hendrix
#
#                 City                     Country                 Phone 1  \
# ...

# %%
df = pd.read_csv("customers-100.csv", na_values=["Sheryl","Baxter", "Chile"])
df.head()
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 0    1.0  DD37Cf93aecA6Dc        NaN       NaN           Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston    Lozano                       NaN
# 2    NaN              NaN        NaN       NaN                       NaN
# 3    NaN              NaN        NaN       NaN                       NaN
# 4    5.0  053d585Ab6b3159     Joanna       NaN  Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0                NaN                         NaN                     NaN
# 1  East Jimmychester                    Djibouti              5153435776
# 2                NaN                         NaN                     NaN
# 3                NaN                         NaN                     NaN
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
#                  Phone 2                     Email Subscription Date  \
# ...

# %%
df = pd.read_csv("customers-100.csv", na_values={
        'First Name': ["Sheryl"],
        'Company': ["Rasmussen Group", "Browning-Simon"]}
    )
df.head(10)
# Out:
#    Index      Customer Id First Name  Last Name                       Company  \
# 0    1.0  DD37Cf93aecA6Dc        NaN     Baxter                           NaN
# 1    2.0  1Ef7b82A4CAAD10    Preston     Lozano                           NaN
# 2    NaN              NaN        NaN        NaN                           NaN
# 3    NaN              NaN        NaN        NaN                           NaN
# 4    5.0  053d585Ab6b3159     Joanna        NaN      Martin, Lang and Andrade
# 5    NaN              NaN        NaN        NaN                           NaN
# 6    7.0  EA4d384DfDbBf77     Darren        NaN  Lester, Woodard and Mitchell
# 7    8.0  0e04AFde9f225dE      Brett     Mullen  Sanford, Davenport and Giles
# 8    9.0  C2dE4dEEc489ae0        NaN     Meyers                           NaN
# 9   10.0  8C2811a503C7c5a   Michelle  Gallagher                  Beck-Hendrix
#
#                 City                     Country                 Phone 1  \
# ...

# %%
df.to_csv('firstFile1.csv')

# %%
df.to_csv("newFile.csv", index=False)

# %%
df.to_csv("newFile1.csv", columns=["First Name","Company","Email"], index=False)

# %%
df.to_csv("newFile2.csv", header=False)

# %%
df = pd.read_excel("file_example.xls", "Data")
df
# Out:
#        Name  Gender        Country  Age    Id
# 0     Dulce  Female  United States   32  1562
# 1      Mara  Female  Great Britain   25  1582
# 2    Philip    Male         France   36  2587
# 3  Kathleen  Female  United States   25  3549
# 4   Nereida  Female  United States   58  2468
# 5    Gaston    Male  United States   24  2554
# 6      Etta  Female  Great Britain   56  3598
# 7   Earlean  Female  United States   27  2456
# 8  Vincenza  Female  United States   40  6548

# %%
df.to_excel("newExcel.xlsx")

# %%
df.to_excel("newExcel.xlsx", index=False)

# %%
df.to_excel("newExcel.xlsx", sheet_name="Data", index=False)

# %%
df.to_excel("newExcelFile.xlsx", sheet_name="Data", index=False, startrow=2, startcol=3)

# %%
df1 = pd.DataFrame({
    'stocks': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

df2 = pd.DataFrame({
    'day': ['1/1/2017', '1/2/2017', '1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})

df1
# Out:
#   stocks  price     pe    eps
# 0  GOOGL    845  30.37  27.82
# 1    WMT     65  14.26   4.61
# 2   MSFT     64  30.97   2.12

# %%
df2
# Out:
#         day  temperature  event
# 0  1/1/2017           32   Rain
# 1  1/2/2017           35  Sunny
# 2  1/3/2017           28   Snow

# %%
df1.to_excel("stock.xlsx", sheet_name="price")

# %%
df1.to_excel("stock.xlsx", sheet_name="price", index=False)

# %%
with pd.ExcelWriter('trippleData.xlsx') as writer:
                    df1.to_excel(writer, sheet_name="Stocks")
                    df2.to_excel(writer, sheet_name="Temperature")
                    df.to_excel(writer, sheet_name="Employee", index=False)
